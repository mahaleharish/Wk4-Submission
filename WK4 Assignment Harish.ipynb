# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: Harish M**
#
# Occupation: Datascientist

# %% [markdown]
# *I am interested in data science because it is fascinating to extract actionable insights from data and apply those for business improvments*

# %% [markdown]
# ### Below code is supposed to give the output of multiplication of two numbers

# %%
2*3
# Out:
# 6

# %% [markdown]
# Horizontal rule
#
# -----------------
#
# Bulleted list
# - item 1
# - item 2
#
# Numbered list
# 1. Item 1
# 2. Item 2
#
#
# ~strikethrough~
#
# Table
#
# Col1 | Col2 | Col3
# ---|---|---
# val1 | val2 | val3
